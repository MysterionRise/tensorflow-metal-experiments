# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
import tensorflow as tf
from tensorflow import keras

# list of all physical devices
print(tf.config.list_physical_devices())

gpus = tf.config.list_physical_devices('GPU')
tf.config.set_visible_devices(gpus[0], 'GPU')

# train on CPU only uncomment out if you want CPU only training
# tf.config.set_visible_devices([], 'CPU')

# tf.debugging.set_log_device_placement(True)
# Out:
# 2024-05-14 21:11:28.717291: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-14 21:11:28.738889: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-14 21:11:28.738907: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-14 21:11:28.739387: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-14 21:11:28.742790: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-14 21:11:31.975668: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-05-14 21:11:38.705551: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-14 21:11:38.727509: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-14 21:11:38.727535: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# CIFAR 100 have 100 classes
no_classes = 100
img_width, img_height, img_num_channels = 32, 32, 3
input_shape = (img_width, img_height, img_num_channels)

model = Sequential()
model.add(Conv2D(input_shape=input_shape,filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=no_classes, activation="softmax"))

model.summary()
# Out:
# 2024-05-14 21:11:38.744788: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 64)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 256)         590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 512)         0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  conv2d_11 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  conv2d_12 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  max_pooling2d_4 (MaxPoolin  (None, 1, 1, 512)         0
#  g2D)
#
#  dropout (Dropout)           (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 100)               409700
#
# =================================================================
# Total params: 34006948 (129.73 MB)
# Trainable params: 34006948 (129.73 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2024-05-14 21:11:38.744825: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-14 21:11:38.744835: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-14 21:11:38.822541: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-14 21:11:38.822571: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-14 21:11:38.822575: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-05-14 21:11:38.822592: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-14 21:11:38.822605: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9517 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
import time
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
start = time.time()
model.compile(optimizer=keras.optimizers.legacy.Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=50, batch_size=128)
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Fitting took: {}".format(time.time() - start))
test_acc
# Out:
# Epoch 1/50
# 2024-05-14 21:11:40.199053: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-05-14 21:11:40.324013: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-05-14 21:11:41.016425: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-14 21:11:41.594358: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 391/391 [==============================] - 14s 22ms/step - loss: 4.5158 - accuracy: 0.0149
# Epoch 2/50
# 391/391 [==============================] - 7s 18ms/step - loss: 4.1756 - accuracy: 0.0368
# Epoch 3/50
# 391/391 [==============================] - 7s 18ms/step - loss: 3.9407 - accuracy: 0.0640
# Epoch 4/50
# 391/391 [==============================] - 7s 19ms/step - loss: 3.7461 - accuracy: 0.0953
# Epoch 5/50
# 391/391 [==============================] - 7s 19ms/step - loss: 3.5730 - accuracy: 0.1261
# Epoch 6/50
# 391/391 [==============================] - 7s 18ms/step - loss: 3.4165 - accuracy: 0.1531
# Epoch 7/50
# 391/391 [==============================] - 7s 18ms/step - loss: 3.2502 - accuracy: 0.1819
# Epoch 8/50
# 391/391 [==============================] - 7s 18ms/step - loss: 3.0690 - accuracy: 0.2171
# Epoch 9/50
# 391/391 [==============================] - 7s 18ms/step - loss: 2.8912 - accuracy: 0.2473
# Epoch 10/50
# 391/391 [==============================] - 7s 18ms/step - loss: 2.7109 - accuracy: 0.2841
# Epoch 11/50
# 391/391 [==============================] - 7s 18ms/step - loss: 2.5125 - accuracy: 0.3221
# Epoch 12/50
# 391/391 [==============================] - 7s 18ms/step - loss: 2.3136 - accuracy: 0.3627
# Epoch 13/50
# 391/391 [==============================] - 7s 18ms/step - loss: 2.0974 - accuracy: 0.4107
# Epoch 14/50
# 391/391 [==============================] - 7s 18ms/step - loss: 1.8842 - accuracy: 0.4568
# Epoch 15/50
# 391/391 [==============================] - 7s 19ms/step - loss: 1.6761 - accuracy: 0.5030
# Epoch 16/50
# 391/391 [==============================] - 7s 18ms/step - loss: 1.4728 - accuracy: 0.5566
# Epoch 17/50
# 391/391 [==============================] - 7s 18ms/step - loss: 1.2952 - accuracy: 0.6011
# Epoch 18/50
# 391/391 [==============================] - 7s 18ms/step - loss: 1.1141 - accuracy: 0.6559
# Epoch 19/50
# 391/391 [==============================] - 7s 18ms/step - loss: 0.9777 - accuracy: 0.6960
# Epoch 20/50
# 391/391 [==============================] - 7s 18ms/step - loss: 0.8538 - accuracy: 0.7315
# Epoch 21/50
# 391/391 [==============================] - 7s 18ms/step - loss: 0.7568 - accuracy: 0.7597
# Epoch 22/50
# 391/391 [==============================] - 7s 18ms/step - loss: 0.6500 - accuracy: 0.7944
# Epoch 23/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.5719 - accuracy: 0.8201
# Epoch 24/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.5037 - accuracy: 0.8406
# Epoch 25/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.4567 - accuracy: 0.8551
# Epoch 26/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.4117 - accuracy: 0.8694
# Epoch 27/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.3704 - accuracy: 0.8826
# Epoch 28/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.3430 - accuracy: 0.8929
# Epoch 29/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.3159 - accuracy: 0.9028
# Epoch 30/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.2963 - accuracy: 0.9048
# Epoch 31/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.2877 - accuracy: 0.9106
# Epoch 32/50
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2676 - accuracy: 0.9156
# Epoch 33/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.2428 - accuracy: 0.9234
# Epoch 34/50
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2316 - accuracy: 0.9272
# Epoch 35/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.2139 - accuracy: 0.9324
# Epoch 36/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.2195 - accuracy: 0.9323
# Epoch 37/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.2034 - accuracy: 0.9362
# Epoch 38/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.1985 - accuracy: 0.9387
# Epoch 39/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.1794 - accuracy: 0.9444
# Epoch 40/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.1795 - accuracy: 0.9445
# Epoch 41/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.1723 - accuracy: 0.9462
# Epoch 42/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.1644 - accuracy: 0.9476
# Epoch 43/50
# 391/391 [==============================] - 8s 20ms/step - loss: 0.1669 - accuracy: 0.9476
# Epoch 44/50
# 391/391 [==============================] - 8s 20ms/step - loss: 0.1611 - accuracy: 0.9496
# Epoch 45/50
# 391/391 [==============================] - 8s 20ms/step - loss: 0.1579 - accuracy: 0.9505
# Epoch 46/50
# 391/391 [==============================] - 8s 20ms/step - loss: 0.1490 - accuracy: 0.9533
# Epoch 47/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.1462 - accuracy: 0.9546
# Epoch 48/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.1380 - accuracy: 0.9575
# Epoch 49/50
# 391/391 [==============================] - 7s 19ms/step - loss: 0.1484 - accuracy: 0.9536
# Epoch 50/50
# 391/391 [==============================] - 8s 19ms/step - loss: 0.1311 - accuracy: 0.9599
# 313/313 [==============================] - 2s 5ms/step - loss: 6.8981 - accuracy: 0.3250
# Fitting took: 377.45256185531616
# 0.32499998807907104
